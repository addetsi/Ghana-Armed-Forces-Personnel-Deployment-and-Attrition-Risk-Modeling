# %%
#import Libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
from scipy import stats
from scipy.stats import chi2_contingency 
import warnings 
warnings.filterwarnings('ignore')

#import project confiuration
import sys
sys.path.append('..')
import config

#set visualization style
sns.set_style('whitegrid')
sns.set_palette('Set2')
plt.rcParams['figure.figsize'] = (14, 6)
plt.rcParams['font.size'] = 10

# Set random seed
np.random.seed(config.RANDOM_SEED)

print("Libraries imported successfully")
print(f"Matplotlib version: {plt.matplotlib.__version__}")
print(f"Seaborn version: {sns.__version__}")
# Out:
# Configuration loaded successfully!
# Project root: C:\Users\hp\Desktop\gaf\Ghana-Armed-Forces-Personnel-Deployment-and-Attrition-Risk-Modeling
# Random seed: 42
# Target sample size: 1000 personnel
# Libraries imported successfully
# Matplotlib version: 3.7.2
# Seaborn version: 0.12.2

# %% [markdown]
# # Load Data

# %%
#load the dataset 
data_path = config.RAW_DATA_DIR/ config.PERSONNEL_DATA_FILE
df = pd.read_csv(data_path)

df['contract_end_data'] = pd.to_datetime(df['contract_end_date'])

print(f"Data loaded successfully")
print(f"Shape: {df.shape}")
print(f"\n Some rows")
df.head()
# Out:
# Data loaded successfully
# Shape: (1000, 52)
#
#  Some rows
#   personnel_id             name  age  gender service_branch     rank  \
# 0     MIL00001     Allison Hill   35    Male           Army  Officer
# 1     MIL00002      Noah Rhodes   23  Female           Army   Junior
# 2     MIL00003  Angie Henderson   29    Male           Army   Junior
# 3     MIL00004    Daniel Wagner   20    Male      Air Force   Junior
# 4     MIL00005  Cristian Santos   21  Female           Navy   Junior
#
#                 MOS  years_of_service contract_end_date marital_status  ...  \
# 0   Military Police                18        2026-09-22         Single  ...
# 1  Cyber Operations                 2        2025-03-01       Divorced  ...
# 2    Special Forces                 5        2027-01-20        Married  ...
# 3          Aviation                 5        2028-08-12        Married  ...
# 4    Administration                 1        2027-01-20        Married  ...
#
#    peer_rating_score civilian_job_offers  financial_stress_indicator  \
# 0               81.3                 0.0                         Low
# 1                NaN                 0.0                         Low
# 2               73.8                 0.0                         Low
# 3               79.3                 1.0                      Medium
# 4                NaN                 NaN                         Low
#
#    family_support_score  relocation_willingness  attrition_risk_score  \
# 0                  95.6                     Low              0.000000
# 1                  24.6                    High             34.614493
# 2                  61.7                  Medium              0.000000
# 3                  69.3                  Medium             25.940718
# 4                  38.7                     Low             19.649121
#
#    attrition_risk  readiness_score  readiness_category  contract_end_data
# 0             NaN             62.0           Not Ready         2026-09-22
# 1        LOW_RISK             70.9             Limited         2025-03-01
# 2             NaN             67.3           Not Ready         2027-01-20
# 3        LOW_RISK             73.4             Limited         2028-08-12
# 4        LOW_RISK             76.0             Limited         2027-01-20
#
# [5 rows x 52 columns]

# %%
#info 
print("Dataset Information")
print("-"*60)
df.info()
# Out:
# Dataset Information
# ------------------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 52 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   personnel_id                    1000 non-null   object
#  1   name                            1000 non-null   object
#  2   age                             1000 non-null   int64
#  3   gender                          1000 non-null   object
#  4   service_branch                  1000 non-null   object
#  5   rank                            1000 non-null   object
#  6   MOS                             1000 non-null   object
#  7   years_of_service                1000 non-null   int64
#  8   contract_end_date               1000 non-null   object
#  9   marital_status                  1000 non-null   object
#  10  dependents                      1000 non-null   int64
#  11  education_level                 1000 non-null   object
#  12  months_until_contract_end       1000 non-null   int64
#  13  total_training_hours            1000 non-null   int64
#  14  specialized_courses_completed   1000 non-null   int64
#  15  training_score_average          1000 non-null   float64
#  16  certifications_held             1000 non-null   int64
#  17  days_since_last_training        1000 non-null   int64
#  18  skills_current                  1000 non-null   bool
#  19  training_budget_spent           1000 non-null   int64
#  20  health_index                    1000 non-null   float64
#  21  physical_fitness_score          1000 non-null   float64
#  22  medical_restrictions            1000 non-null   bool
#  23  days_on_medical_leave           925 non-null    float64
#  24  mental_health_status            965 non-null    object
#  25  wellness_program_participation  930 non-null    object
#  26  annual_leave_taken              1000 non-null   int64
#  27  emergency_leave_incidents       930 non-null    float64
#  28  unauthorized_absences           1000 non-null   int64
#  29  leave_balance                   1000 non-null   int64
#  30  leave_to_service_ratio          1000 non-null   float64
#  31  total_deployments               1000 non-null   int64
#  32  months_deployed_last_3yrs       1000 non-null   int64
#  33  deployment_type                 914 non-null    object
#  34  months_since_last_deployment    1000 non-null   int64
#  35  mission_performance_rating      1000 non-null   int64
#  36  combat_exposure_level           327 non-null    object
#  37  performance_review_score        1000 non-null   float64
#  38  commendations                   1000 non-null   int64
#  39  disciplinary_actions            1000 non-null   int64
#  40  leadership_potential_score      1000 non-null   float64
#  41  promotion_eligible              1000 non-null   bool
#  42  peer_rating_score               860 non-null    float64
#  43  civilian_job_offers             953 non-null    float64
#  44  financial_stress_indicator      1000 non-null   object
#  45  family_support_score            889 non-null    float64
#  46  relocation_willingness          1000 non-null   object
#  47  attrition_risk_score            1000 non-null   float64
#  48  attrition_risk                  907 non-null    object
#  49  readiness_score                 1000 non-null   float64
#  50  readiness_category              1000 non-null   object
#  51  contract_end_data               1000 non-null   datetime64[ns]
# dtypes: bool(3), datetime64[ns](1), float64(13), int64(18), object(17)
# memory usage: 385.9+ KB

# %%
#summary 
print("\nNumeric Feature Summary")
print("-"*60)
df.describe().round(3).T
# Out:
# Numeric Feature Summary
# ------------------------------------------------------------
#                                 count                           mean  \
# age                            1000.0                         29.409
# years_of_service               1000.0                          8.296
# dependents                     1000.0                          2.505
# months_until_contract_end      1000.0                         24.285
# total_training_hours           1000.0                        659.587
# specialized_courses_completed  1000.0                          4.607
# training_score_average         1000.0                         80.082
# certifications_held            1000.0                          3.485
# days_since_last_training       1000.0                        355.991
# training_budget_spent          1000.0                       9442.117
# health_index                   1000.0                         85.668
# physical_fitness_score         1000.0                         79.212
# days_on_medical_leave           925.0                         13.137
# annual_leave_taken             1000.0                         15.011
# emergency_leave_incidents       930.0                          0.886
# unauthorized_absences          1000.0                          0.218
# leave_balance                  1000.0                         14.989
# leave_to_service_ratio         1000.0                          4.097
# total_deployments              1000.0                          3.032
# months_deployed_last_3yrs      1000.0                         18.021
# months_since_last_deployment   1000.0                        102.318
# mission_performance_rating     1000.0                          3.491
# performance_review_score       1000.0                         81.885
# commendations                  1000.0                          3.458
# disciplinary_actions           1000.0                          0.134
# leadership_potential_score     1000.0                         51.674
# peer_rating_score               860.0                         81.208
# civilian_job_offers             953.0                          0.418
# family_support_score            889.0                         69.951
# attrition_risk_score           1000.0                         28.442
# readiness_score                1000.0                         71.154
# contract_end_data                1000  2026-12-29 13:11:59.999999744
#
#                                                min                  25%  \
# age                                           18.0                 24.0
# years_of_service                               0.0                  3.0
# dependents                                     0.0                  1.0
# months_until_contract_end                      1.0                 13.0
# total_training_hours                           0.0               256.75
# specialized_courses_completed                  0.0                  2.0
# training_score_average                        60.0                 73.6
# certifications_held                            0.0                  2.0
# days_since_last_training                       2.0               170.75
# training_budget_spent                          0.0               4075.5
# health_index                                  55.3               79.375
# physical_fitness_score                        30.4               69.375
# days_on_medical_leave                          0.0                  3.0
# annual_leave_taken                             0.0                 10.0
# emergency_leave_incidents                      0.0                  0.0
# unauthorized_absences                          0.0                  0.0
# leave_balance                                  0.0                 10.0
# leave_to_service_ratio                         0.0                 1.07
# total_deployments                              0.0                  1.0
# months_deployed_last_3yrs                      0.0                  9.0
# months_since_last_deployment                   1.0                 10.0
# mission_performance_rating                     1.0                  3.0
# performance_review_score                      60.0                 76.4
# commendations                                  0.0                  1.0
# disciplinary_actions                           0.0                  0.0
# leadership_potential_score                    19.3                42.15
# peer_rating_score                             38.3                 72.8
# civilian_job_offers                            0.0                  0.0
# family_support_score                           6.6                 58.1
# attrition_risk_score                           0.0               11.615
# readiness_score                               42.4                 64.9
# contract_end_data              2025-01-30 00:00:00  2026-01-25 00:00:00
#
#                                                50%                  75%  \
# age                                           28.0                 35.0
# years_of_service                               6.0                 12.0
# dependents                                     2.5                  4.0
# months_until_contract_end                     25.0                 35.0
# total_training_hours                         549.5               998.75
# specialized_courses_completed                  4.0                  7.0
# training_score_average                        79.9                 86.7
# certifications_held                            3.0                  5.0
# days_since_last_training                     348.5                548.5
# training_budget_spent                       8280.0              13155.0
# health_index                                  85.9                 93.0
# physical_fitness_score                        80.0                 91.0
# days_on_medical_leave                          8.0                 17.0
# annual_leave_taken                            15.0                 20.0
# emergency_leave_incidents                      0.0                  1.0
# unauthorized_absences                          0.0                  0.0
# leave_balance                                 15.0                 20.0
# leave_to_service_ratio                       2.105                  4.5
# total_deployments                              3.0                  4.0
# months_deployed_last_3yrs                     18.0                 27.0
# months_since_last_deployment                  20.0                 29.0
# mission_performance_rating                     4.0                  4.0
# performance_review_score                      82.0               87.525
# commendations                                  3.0                 4.25
# disciplinary_actions                           0.0                  0.0
# leadership_potential_score                    51.0               60.225
# peer_rating_score                            81.45                 90.6
# civilian_job_offers                            0.0                  0.0
# family_support_score                          70.4                 82.7
# attrition_risk_score                        25.166               42.493
# readiness_score                               71.3               77.525
# contract_end_data              2027-01-20 00:00:00  2027-11-16 00:00:00
#
#                                                max       std
# age                                           54.0     7.889
# years_of_service                              29.0     6.615
# dependents                                     5.0     1.701
# months_until_contract_end                     47.0    13.244
# total_training_hours                        2000.0   523.211
# specialized_courses_completed                 15.0     3.347
# training_score_average                       100.0     9.398
# certifications_held                            8.0      1.93
# days_since_last_training                     729.0   212.171
# training_budget_spent                      34622.0  7133.439
# health_index                                 100.0     9.507
# physical_fitness_score                       100.0     14.67
# days_on_medical_leave                        173.0    17.241
# annual_leave_taken                            30.0     6.592
# emergency_leave_incidents                      5.0     1.155
# unauthorized_absences                          3.0     0.566
# leave_balance                                 30.0     6.592
# leave_to_service_ratio                        30.0     5.369
# total_deployments                              8.0     2.082
# months_deployed_last_3yrs                     35.0    10.653
# months_since_last_deployment                 999.0   275.359
# mission_performance_rating                     5.0     0.991
# performance_review_score                     100.0     8.359
# commendations                                 10.0     2.747
# disciplinary_actions                           3.0     0.537
# leadership_potential_score                   100.0    13.329
# peer_rating_score                            100.0    12.197
# civilian_job_offers                            3.0     0.879
# family_support_score                         100.0    18.507
# attrition_risk_score                         100.0     21.62
# readiness_score                               99.3      9.11
# contract_end_data              2028-11-10 00:00:00       NaN
